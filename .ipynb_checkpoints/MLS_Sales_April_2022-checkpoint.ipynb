# %% [markdown]
# ## Exploratory Analysis of Stellar MLS Data of Residential Real-Estate Listings that closed in the month of April 2022
#
# In this markdown I will be practicing some basic data cleaning with the pandas package, and visual presentations with mayplotlib.

# %%
import re
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# ### Inputting Data
# In this directory, there is a .csv file labaled "Houses.csv". This data set was extracted from the Stellar MLS of all residential real-estate listings that closed in the month of April 2022.
# I use the __read_csv()__ function in the pandas library to create a dataframe named __df__. I also rename some of the columns to have underscores so there are no spaces in the variables. I have printed the

# %%
# read .csv file to dataframe file
# df = pd.read_csv("Houses.csv") 

# rename columns with spaces to underscores
# df = df.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})

# display columns below
# print(df.columns)
# Out:
# Index(['#', 'ML Number', 'Close_Price', 'Original_List_Price', 'List_Date',
#        'Close_Date', 'Status', 'Address', 'City', 'Zip',
#        'Legal Subdivision Name', 'Heated Area', 'Current Price', 'Beds',
#        'Full Baths', 'Half Baths', 'Year Built', 'Pool', 'Property Style',
#        'Tax', 'CDOM', 'ADOM', 'Days to Contract', 'Sold Terms', 'LP / SqFt',
#        'SP/SqFt', 'SP / LP', 'List Office', 'List Agent', 'List Agent ID',
#        'Selling Office ID', 'Selling Agent ID', 'LSC List Side',
#        'List Office Primary Board ID'],
#       dtype='object')

# %%
df0 = pd.read_csv("Houses2.csv") 
df0 = df0.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})
df1 = pd.read_csv("Houses3.csv") 
df1 = df1.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})

frames = [df1, df0]
# df3 = pd.concat(frames)
df = df1.append(df0, ignore_index=True)
df = df.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})

# %% [markdown]
# ### Notes for code below
#
# NOTE 1: This replaces with Series.str.replace https://stackoverflow.com/questions/22588316/pandas-applying-regex-to-replace-values
#
# https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/

# %%
# Column Cloze_Price is an obj file, here we convert it to a string.
df["Close_Price"] = df["Close_Price"].astype('string')
# We need to remove characters from the price (e.g., $400,000 to 400000), we use str.replace function
df['Close_Price'] = df['Close_Price'].str.replace(r'\D+', '', regex=True).astype('int') # NOTE 1

# Same as above but for Column Original_List_Price
df["Original_List_Price"] = df["Original_List_Price"].astype('string')
# Same as above but for Column Original_List_Price
df['Original_List_Price'] = df['Original_List_Price'].str.replace(r'\D+', '', regex=True).astype('int')

df.dtypes
# Out:
# #                                 int64
# ML Number                        object
# Close_Price                       int32
# Original_List_Price               int32
# List_Date                        object
# Close_Date                       object
# Status                           object
# Address                          object
# City                             object
# Zip                               int64
# Legal Subdivision Name           object
# Heated Area                      object
# Current Price                    object
# Beds                              int64
# Full Baths                        int64
# Half Baths                        int64
# Year Built                      float64
# Pool                             object
# Property Style                   object
# Tax                              object
# CDOM                              int64
# ADOM                              int64
# Days to Contract                  int64
# ...

# %% [markdown]
# ### Creating New Variables: OLP_Median & CP_Median
#
# I want to explore the relationship sale price has depending on if it is higher than the median or lower than the median. I will create two new columns in my data set for two seperate categories:
# __OLP_Median__ & __CP_Median__.

# %%
median_Original = df["Original_List_Price"].median() 

# create a list of our conditions
conditions = [ 
    (df["Original_List_Price"] <= median_Original),
    (df["Original_List_Price"] > median_Original)
]

# create a list of the values we want to assign for each condition
values = ['Lower_Median', 'Higher_Median']

# create a new column and use np.select to assign values to it using our lists as arguments
df['Median_OP'] = np.select(conditions, values)

df.head(5)
df.tail(5)
# Out:
#      # ML Number  Close_Price  Original_List_Price   List_Date  Close_Date  \
# 960  1   J945292        86500                86500  04/14/2022  04/14/2022
# 961  1   J945291        86500                86500  04/14/2022  04/14/2022
# 962  1  T3347266        91894                79000  12/27/2021  04/19/2022
# 963  1  P4919841       112500               128500  03/11/2022  04/20/2022
# 964  1  O6014865        86000               100000  04/02/2022  04/20/2022
#
#     Status                         Address     City    Zip  ... SP/SqFt  \
# 960    SLD       2771 L B MCLEOD RD Unit#D  ORLANDO  32805  ...   $87.2
# 961    SLD       2753 L B MCLEOD RD Unit#D  ORLANDO  32805  ...   $87.2
# 962    SLD  5231 VIA HACIENDA CIR Unit#118  ORLANDO  32839  ...  $98.39
# 963    SLD         4005 DOLOMITE ST Unit#B  ORLANDO  32839  ...  $74.55
# 964    SLD                  7129 ODESSA DR  ORLANDO  32818  ...  $63.42
#
#     SP / LP                     List Office                List Agent  \
# ...

# %% [markdown]
# ### Creating New Variables: SP_diff_OLP

# %%
df["SP_diff_OLP"] = df.apply(lambda row: row.Close_Price - row.Original_List_Price, axis = 1)

# %%
plt.plot()

fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Median_OP'], df['SP_diff_OLP'])
ax.set_xlabel('Median_OP')
ax.set_ylabel('SP_diff_OLP')
plt.show()



# sns.displot(data=df, x="total_bill", col="time", kde=True)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Beds'], df['Close_Price'])
ax.set_xlabel('Beds')
ax.set_ylabel('Close_Price')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Year Built'], df['Close_Price'])
ax.set_xlabel('Year Built')
ax.set_ylabel('Close_Price')
plt.show()

# %%
fig, ax = plt.subplots()
ax.fill_between(df['Close_Price'], df['Original_List_Price'], alpha=.5, linewidth=0)
plt.show()

# %%
sns.set(style='ticks', context='talk')
sns.swarmplot('Median_OP', 'SP_diff_OLP', data=df)
sns.despine()
# Out:
# C:\Users\alexs\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\alexs\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\alexs\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 88.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# fig, ax = plt.subplots()

sns.displot(x = "SP_diff_OLP", hue="Median_OP", kind="kde", fill=True,
               data = df)# .ax.set_xlim(-2,2).ax.set_ylim(0,2)
plt.xlim(-200000,200000)
#.set_xlim(-100,100)
# ax.set_xlim(-1,1)

#gfg = sns.boxplot(x="Median_OP", y="SP_diff_OLP", data=df)
#gfg.set_ylim(0, 10)
# Out:
# (-200000.0, 200000.0)

# %%
gfg = sns.boxplot(x="Median_OP", y="SP_diff_OLP",
                  data=df)
gfg.set_ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
df[].avg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25676/534806191.py in <module>
# ----> 1 df[SP_diff_OLP].avg()
#
# NameError: name 'SP_diff_OLP' is not defined

# %%
df["SP_diff_OLP]
# Out:
# 4000.0

# %%
# Out:
# Skewness is nan
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25676/2695729508.py in <module>
#       3 target = np.log(df['SP_diff_OLP'])
#       4 print ('Skewness is', target.skew())
# ----> 5 sns.distplot(target)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2672     if hist:
#    2673         if bins is None:
# -> 2674             bins = min(_freedman_diaconis_bins(a), 50)
#    2675         hist_kws.setdefault("alpha", 0.4)
#    2676         hist_kws.setdefault("density", norm_hist)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#    2463         return int(np.sqrt(a.size))
#    2464     else:
# ...
