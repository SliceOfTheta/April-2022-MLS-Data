# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("Orlando.csv")
df.rename(columns={"Property Type": "PropertyType", "Property Style": "PropertyStyle"}, errors="raise")
df.head(100)  # To display the top 100 rows
# Out:
#    Property Type Status           Property Style  List Price List Date  \
# 0            RES   SOLD                      NaN      240000    4/1/22
# 1            RES   SOLD                      NaN      260000    4/1/22
# 2            RES   SOLD  SINGLE FAMILY RESIDENCE      600000    4/1/22
# 3            RES   SOLD  SINGLE FAMILY RESIDENCE      399000    9/8/21
# 4            RES   SOLD  SINGLE FAMILY RESIDENCE      471429   5/23/21
# ..           ...    ...                      ...         ...       ...
# 83           RES   SOLD                TOWNHOUSE      350000   2/25/22
# 84           RES   SOLD  SINGLE FAMILY RESIDENCE      350000    3/3/22
# 85           RES   SOLD  SINGLE FAMILY RESIDENCE      350000   3/15/22
# 86           RES   SOLD  SINGLE FAMILY RESIDENCE      279000   9/17/21
# 87           RES   SOLD              CONDOMINIUM      135000    3/7/22
#
#    City Name  Zip Code  Year Built  Heated (Living) Area  Bedrooms  Bathrooms  \
# 0    ORLANDO     32807        1953                  1323         2        1.0
# 1    ORLANDO     32809        1964                  1175         4        2.0
# 2    ORLANDO     32828        1996                  2603         5        2.0
# 3    ORLANDO     32824        2007                  1622         3        2.0
# 4    ORLANDO     32833        2021                  2300         4        3.0
# ..       ...       ...         ...                   ...       ...        ...
# 83   ORLANDO     32824        2018                  1703         3        2.5
# 84   ORLANDO     32824        1990                  1341         3        2.0
# 85   ORLANDO     32826        1978                  1395         4        2.0
# 86   ORLANDO     32812        1983                  1834         3        2.0
# 87   ORLANDO     32835        1989                   627         1        1.0
#
#    Pool Waterfront (Y/N)  Sale Price Sale Date
# 0     t                f      240000    4/1/22
# 1     t                f      260000    4/1/22
# 2     t                f      600000    4/1/22
# 3     t                f      399000    4/1/22
# 4     t                f      471429    4/1/22
# ..  ...              ...         ...       ...
# 83    t                f      350000    4/1/22
# 84    t                f      350000    4/1/22
# 85    t                f      350000    4/1/22
# 86    t                f      279000    4/1/22
# 87    t                f      135000    4/1/22
#
# [88 rows x 15 columns]

# %%
df.dtypes
# Out:
# Property Type            object
# Status                   object
# Property Style           object
# List Price                int64
# List Date                object
# City Name                object
# Zip Code                  int64
# Year Built                int64
# Heated (Living) Area      int64
# Bedrooms                  int64
# Bathrooms               float64
# Pool                     object
# Waterfront (Y/N)         object
# Sale Price                int64
# Sale Date                object
# dtype: object

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Status')
plt.xlabel('Property Type');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30492/799868315.py in <module>
# ----> 1 df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
#       2 plt.title("Number of cars by make")
#       3 plt.ylabel('Status')
#       4 plt.xlabel('Property Type');
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Make'
