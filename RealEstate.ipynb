# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("Orlando.csv")
df = df.rename(columns={'Property Type': "PT", 'Status': "Stat", 'Property Style': "PS", 'List Price': "LP", 'List Date': "LD",
       'City Name': "CN", 'Zip Code': "ZIP", 'Year Built': "YEAR", 'Heated (Living) Area': "SQFT",
       'Bedrooms': "BEDS", 'Bathrooms': "BATHS", 'Pool': "POOL", 'Waterfront (Y/N)': "WATER", 'Sale Price': "SP",
       'Sale Date': "SD"})
df.head(100)  # To display the top 100 rows
# Out:
#      PT  Stat                       PS      LP       LD       CN    ZIP  YEAR  \
# 0   RES  SOLD                      NaN  240000   4/1/22  ORLANDO  32807  1953
# 1   RES  SOLD                      NaN  260000   4/1/22  ORLANDO  32809  1964
# 2   RES  SOLD  SINGLE FAMILY RESIDENCE  600000   4/1/22  ORLANDO  32828  1996
# 3   RES  SOLD  SINGLE FAMILY RESIDENCE  399000   9/8/21  ORLANDO  32824  2007
# 4   RES  SOLD  SINGLE FAMILY RESIDENCE  471429  5/23/21  ORLANDO  32833  2021
# ..  ...   ...                      ...     ...      ...      ...    ...   ...
# 83  RES  SOLD                TOWNHOUSE  350000  2/25/22  ORLANDO  32824  2018
# 84  RES  SOLD  SINGLE FAMILY RESIDENCE  350000   3/3/22  ORLANDO  32824  1990
# 85  RES  SOLD  SINGLE FAMILY RESIDENCE  350000  3/15/22  ORLANDO  32826  1978
# 86  RES  SOLD  SINGLE FAMILY RESIDENCE  279000  9/17/21  ORLANDO  32812  1983
# 87  RES  SOLD              CONDOMINIUM  135000   3/7/22  ORLANDO  32835  1989
#
# ...

# %%
df.dtypes
print
# Out:
# <function print>

# %%
df.PS.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of Sales by Property Type")
plt.ylabel('Sales')
plt.xlabel('Property Style');

# %%
print(df.columns)
# Out:
# Index(['Property Type', 'Status', 'Property Style', 'List Price', 'List Date',
#        'City Name', 'Zip Code', 'Year Built', 'Heated (Living) Area',
#        'Bedrooms', 'Bathrooms', 'Pool', 'Waterfront (Y/N)', 'Sale Price',
#        'Sale Date'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#              LP       ZIP      YEAR      SQFT      BEDS     BATHS        SP
# LP     1.000000  0.191694  0.299125  0.794455  0.602780  0.741321  1.000000
# ZIP    0.191694  1.000000  0.460387  0.241054  0.256249  0.261899  0.191694
# YEAR   0.299125  0.460387  1.000000  0.372701  0.204673  0.389764  0.299125
# SQFT   0.794455  0.241054  0.372701  1.000000  0.765692  0.857648  0.794455
# BEDS   0.602780  0.256249  0.204673  0.765692  1.000000  0.736135  0.602780
# BATHS  0.741321  0.261899  0.389764  0.857648  0.736135  1.000000  0.741321
# SP     1.000000  0.191694  0.299125  0.794455  0.602780  0.741321  1.000000

# %% [raw]
# Each square shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases. The diagonals are all 1/dark green because those squares are correlating each variable to itself (so it's a perfect correlation). For the rest the larger the number and darker the color the higher the correlation between the two variables. The plot is also symmetrical about the diagonal since the same two variables are being paired together in those squares.

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['LP'], df['SP'])
ax.set_xlabel('List Price')
ax.set_ylabel('Sale Price')
plt.show()

# %%
df = pd.read_csv("Houses.csv")
df.head(100)
# Out:
#     # ML Number Close Price Original List Price On Market Date  Close Date  \
# 0   1  O5964340  $2,530,000          $3,500,000     08/19/2021  04/01/2022
# 1   1  O5962884  $3,399,000          $3,495,000     08/02/2021  04/07/2022
# 2   1  O6008003  $3,200,000          $3,400,000     03/04/2022  04/05/2022
# 3   1  O6001539  $2,300,000          $2,900,000     02/07/2022  04/21/2022
# 4   1  O5940273  $1,890,000          $2,495,000     05/01/2021  04/08/2022
# .. ..       ...         ...                 ...            ...         ...
# 95  1  O6008050    $185,000            $195,000     03/11/2022  04/11/2022
# 96  1  O6010320    $230,000            $195,000     03/15/2022  04/19/2022
# 97  1  O6004889    $196,000            $194,900     02/18/2022  04/04/2022
# 98  1  O6006166    $196,000            $189,900     02/24/2022  04/01/2022
# 99  1  O6004959    $200,000            $187,000     03/18/2022  04/05/2022
#
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'ML Number', 'Close Price', 'Original List Price',
#        'On Market Date', 'Close Date', 'Status', 'Address', 'City', 'Zip',
#        'Legal Subdivision Name', 'Heated Area', 'Current Price', 'Beds',
#        'Full Baths', 'Half Baths', 'Year Built', 'Pool', 'Property Style',
#        'Tax', 'CDOM', 'ADOM', 'Days to Contract', 'Sold Terms', 'LP / SqFt',
#        'SP/SqFt', 'SP / LP', 'List Office', 'List Agent', 'List Agent ID',
#        'Selling Office ID', 'Selling Agent ID', 'LSC List Side',
#        'List Office Primary Board ID'],
#       dtype='object')

# %%
df = df.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16552/651645131.py in <module>
# ----> 1 df = df.rename(columns={'On Market Date': "List_Date", "Close Date": "Close_Date", "Close Price": "Close_Price", "Original List Price": "Original_List_Price"})
#       2 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Close_Price'], df['Original_List_Price'])
ax.set_xlabel('Close Price')
ax.set_ylabel('Listing Price')
plt.show()
